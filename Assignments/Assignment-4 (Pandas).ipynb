# %% [markdown]
# # Pandas Assignment

# %% [markdown]
# ### Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
import pandas as pd
df = pd.Series([1,2,3,4])
df
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# ### Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
sample = [[1,2,3,4], [5,6,7,8]]
df = pd.DataFrame(sample)
df.dtypes
# Out:
# 0    int64
# 1    int64
# 2    int64
# 3    int64
# dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# ### Q3. How do you select rows from a Pandas DataFrame based on a condition?

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Q4. How do you rename columns in a Pandas DataFrame?

# %%
df.rename(columns = {'Name' :'Naam'}, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Naam     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Q5. How do you drop columns in a Pandas DataFrame?

# %%
df.drop("Parch", axis =1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Naam     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
df.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %% [markdown]
# <br>

# %% [markdown]
# ### Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Naam             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# ### Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
df["Cabin"].fillna("Unknown", inplace= True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Naam     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Q9. How do you concatenate two Pandas DataFrames?

# %%
df1 = pd.DataFrame({ "roll_no": [1,2,3,4],
                     "name": ["ayn rand", "dostoevsky", "nietzsche", "kant"]})

df2 = pd.DataFrame({"roll_no": [5,6,7,8],
                    "name": ["jiddu krishnamurti", "ramana maharshi", "aurobindo", "vivekananda"]})

frames = [df1, df2]

answer = pd.concat(frames)
answer
# Out:
#    roll_no                name
# 0        1            ayn rand
# 1        2          dostoevsky
# 2        3           nietzsche
# 3        4                kant
# 0        5  jiddu krishnamurti
# 1        6     ramana maharshi
# 2        7           aurobindo
# 3        8         vivekananda

# %% [markdown]
# <br>

# %% [markdown]
# ### Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
df1 = pd.DataFrame({ "roll_no": [1,2,3,4],
                     "name": ["ayn rand", "dostoevsky", "nietzsche", "kant"]})

df2 = pd.DataFrame({"roll_no": [5,6,7,8],
                    "name": ["jiddu krishnamurti", "ramana maharshi", "aurobindo", "vivekananda"],
                    "theme": ["self-awareness", "who am I?", "Integral Yoga", "Not Sure"]})

display(df1)
display(df2)
df1.merge(df2["theme"])
# Out:
#    roll_no        name
# 0        1    ayn rand
# 1        2  dostoevsky
# 2        3   nietzsche
# 3        4        kant
#    roll_no                name           theme
# 0        5  jiddu krishnamurti  self-awareness
# 1        6     ramana maharshi       who am I?
# 2        7           aurobindo   Integral Yoga
# 3        8         vivekananda        Not Sure
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In [22], line 10
#       8 display(df1)
#       9 display(df2)
# ---> 10 df1.merge(df2["theme"])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10090, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10071 @Substitution("")
#   10072 @Appender(_merge_doc, indents=2)
#   10073 def merge(
#    (...)
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Q11. How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q12. How do you pivot a Pandas DataFrame?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q13. How do you change the data type of a column in a Pandas DataFrame?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q14. How do you sort a Pandas DataFrame by a specific column?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q15. How do you create a copy of a Pandas DataFrame?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q17. How do you calculate the mean of a column in a Pandas DataFrame?

# %%
df["Age"].mean(axis=0)
# Out:
# 29.69911764705882

# %% [markdown]
# <br>

# %% [markdown]
# ### Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
df["Age"].std(axis=0)
# Out:
# 14.526497332334042

# %% [markdown]
# <br>

# %% [markdown]
# ### Q19. How do you calculate the correlation between two columns in a Pandas DataFrame?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q20. How do you select specific columns in a DataFrame using their labels?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q21. How do you select specific rows in a DataFrame using their indexes?

# %% [markdown]
# <br>

# %% [markdown]
# ### Q22. How do you sort a DataFrame by a specific column?

# %%
df.sort

# %% [markdown]
# <br>

# %% [markdown]
# ### Q23. How do you create a new column in a DataFrame based on the values of another column?

# %%
df['column'] = df['SibSp'] + df['Parch']
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Q24. How do you remove duplicates from a DataFrame?

# %%
df.drop_duplicates()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Q25. What is the difference between .loc and .iloc in Pandas?

# %%
# .loc is used to locate data using index number( index starting from as user defined it)
df.set_index('PassengerId', inplace=True) # changing index to passenger id
df.loc[2]
# Out:
# Survived                                                    1
# Pclass                                                      1
# Name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                    female
# Age                                                      38.0
# SibSp                                                       1
# Parch                                                       0
# Ticket                                               PC 17599
# Fare                                                  71.2833
# Cabin                                                     C85
# Embarked                                                    C
# Name: 2, dtype: object

# %%
# # .iloc is used to locate data using index number( index starting from 0)
df.iloc[1]
# Out:
# Survived                                                    1
# Pclass                                                      1
# Name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                    female
# Age                                                      38.0
# SibSp                                                       1
# Parch                                                       0
# Ticket                                               PC 17599
# Fare                                                  71.2833
# Cabin                                                     C85
# Embarked                                                    C
# Name: 2, dtype: object
